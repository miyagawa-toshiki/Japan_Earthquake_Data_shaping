# %%
import pandas as pd
#現在の最大表示列数の出力
pd.get_option("display.max_columns")
#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)
import pandas as pd
#現在の最大表示行数の出力
pd.get_option("display.max_rows")
#最大表示行数の指定（ここでは50行を指定）
pd.set_option('display.max_rows', 151)

# %%
#['index','レコード種別ヘッダー','時刻','西暦','月','日','時','分','秒','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数']
#df19=pd.read_csv('dat/i2019.dat', sep=';', encoding='shift-jis')#,names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df19=pd.read_csv('dat/i2019.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df18=pd.read_csv('dat/i2018.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df17=pd.read_csv('dat/i2017.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df16=pd.read_csv('dat/i2016.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df15=pd.read_csv('dat/i2015.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df14=pd.read_csv('dat/i2014.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df13=pd.read_csv('dat/i2013.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df12=pd.read_csv('dat/i2012.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df11=pd.read_csv('dat/i2011.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df10=pd.read_csv('dat/i2010.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df09=pd.read_csv('dat/i2009.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df08=pd.read_csv('dat/i2008.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df07=pd.read_csv('dat/i2007.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df06=pd.read_csv('dat/i2006.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df05=pd.read_csv('dat/i2005.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df04=pd.read_csv('dat/i2004.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df03=pd.read_csv('dat/i2003.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df02=pd.read_csv('dat/i2002.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
df01=pd.read_csv('dat/i2001.dat', sep=';', encoding='shift-jis',names=['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号','小地域区分番号','震央地名','観測点数'])
# import os
# import glob
# os.chdir(ファイルが格納されているディレクトリ)
# df = pd.DataFrame(columns = [])
# for i in glob.glob("*地震リスト*"):
#     tmp = pd.read_csv(i)
#     df = pd.concat([df, tmp])

# %%
#for row in df19['index']:
#    print(row)

# %%
dfs = [df19,df18,df17,df16,df15,df14,df13,df12,df11,df10,df09,df08,df07,df06,df05,df04,df04,df03,df02,df01]
#df = pd.concat(dfs)
df = pd.concat(dfs, axis=0, join='inner', ignore_index=True)

# %%
drop_index=[]
for i in range(len(df)):
    if df['index'][i][0].isdecimal():
        drop_index.append(i)

# %%
df = df.drop(drop_index)

# %%
#for row in df['index']:
#    print(row)

# %%
df
# Out:
#                                                      index  レコード種別ヘッダー  時刻  \
# 0        A2019010104042854 018 432000 061 1460541 097 5...         NaN NaN
# 2        A2019010106533565 020 354111 057 1404558 082 4...         NaN NaN
# 5        A2019010110014516 012 320410 031 1315008 065 3...         NaN NaN
# 7        A2019010118455550 012 241154 057 1241409 057 1...         NaN NaN
# 11       A2019010118551331 014 241096 061 1241460 061 1...         NaN NaN
# ...                                                    ...         ...  ..
# 1526485  A2001123103411905 003 351982 012 1331967 011  ...         NaN NaN
# 1526487  A200112311226     99  3443   99  13926   99   ...         NaN NaN
# 1526489  A200112311407     99  3443   99  13926   99   ...         NaN NaN
# 1526491  A200112311518     99  3443   99  13926   99   ...         NaN NaN
# 1526493  A200112311822     99  3443   99  13926   99   ...         NaN NaN
#
# ...

# %%
df=df.reset_index(drop=True)

# %%
for row in df['index'][0:10]:
    print(row[45:49])
# Out:
# 5120
# 4665
# 3404
# 1448
# 1448
# 4452
# 6581
# 3213
# 5138
# 3362

# %%
#['index','レコード種別ヘッダー','時刻','緯度','経度','深さ','マグニチュード','最大震度','被害規模','津波規模','大地域区分番号',
#'小地域区分番号','震央地名','観測点数']
for i in range(len(df)):
    df['レコード種別ヘッダー'][i]=df['index'][i][0]
    df['時刻'][i]=df['index'][i][1:13]
    df['緯度'][i]=df['index'][i][22:28]
    df['経度'][i]=df['index'][i][33:40]
    df['深さ'][i]=df['index'][i][45:49]
    df['マグニチュード'][i]=df['index'][i][53:54]
    df['最大震度'][i]=df['index'][i][61:62] #最大震度
    df['被害規模'][i]=df['index'][i][62:63]
    df['津波規模'][i]=df['index'][i][63:64]
    df['大地域区分番号'][i]=df['index'][i][64:65] #大地域区分番号
    df['小地域区分番号'][i]=df['index'][i][65:68] #小地域区分番号
    df['震央地名'][i]=df['index'][i][68:84] #震央地名
    df['観測点数'][i]=df['index'][i][85:95]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['時刻']=df['時刻'].astype('int')

# %%
df=df.sort_values('時刻',ascending=True)

# %%
df=df.reset_index(drop=True)

# %%
import datetime
#dt = datetime . datetime ( 2020 , 1 , 1 )
# print(int(str(df['時刻'][0])[0:4]))
# print(int(str(df['時刻'][0])[4:6]))
# print(int(str(df['時刻'][0])[6:8]))
# print(int(str(df['時刻'][0])[8:10]))
# print(int(str(df['時刻'][0])[10:12]))
# print(int(str(df['時刻'][0])[12:14]))
#dt=datetime.datetime(int(str(df['時刻'][0])[0:4]),int(str(df['時刻'][0])[4:6]),int(str(df['時刻'][0])[6:8]),\
#                     int(str(df['時刻'][0])[8:10]),int(str(df['時刻'][0])[10:12]),int(str(df['時刻'][0])[12:14]))
#dt

list_dt=[]
for i in range(len(df)):
    dt=datetime.datetime(int(str(df['時刻'][i])[0:4]),int(str(df['時刻'][i])[4:6]),int(str(df['時刻'][i])[6:8]),\
                     int(str(df['時刻'][i])[8:10]),int(str(df['時刻'][i])[10:12]))#,int(str(df['時刻'][i])[12:14]))
    list_dt.append(dt)
#print(list_dt)
df['dt']=list_dt

# %%
#df=df.reset_index(drop=True)

# %%
df.to_csv('earthquake_20year_full.csv')

# %%
print(df['index'][50000:53000])
df['index']
# Out:
# 50000    A2018051608551098 008 363841 020 1375372 032  ...
# 50001    A2018051610142862 008 363843 019 1375415 028 1...
# 50002    A2018051614433375 003 324422 008 1304845 011 1...
# 50003    A2018051619262821 010 363837 023 1375338 037  ...
# 50004    A2018051620175584 007 404542 015 1411530 026 1...
#                                ...
# 52995    A2019120412012964 004 364877 011 1403199 019  ...
# 52996    A2019120413274096 004 365725 017 1394093 018  ...
# 52997    A2019120413395579 004 341597 009 1330750 014 2...
# 52998    A2019120414050890 003 340281 008 1330374 011 1...
# 52999    A2019120417572726 004 364795 013 1403276 023  ...
# Name: index, Length: 3000, dtype: object
# 0        A2001010100333765 005 342052 015 1390861 025  ...
# 1        A2001010100494386 003 352612 012 1335307 009  ...
# 2        A2001010105123516 014 405400 037 1420572 104 5...
# 3        A2001010109354727 013 361194 033 1394750 041 5...
# 4        A2001010114282906 015 294560 081 1295844 163 2...
# ...
